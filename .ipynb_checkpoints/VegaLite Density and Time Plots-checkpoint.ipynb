# %%
using DataFrames
using Queryverse
using VegaLite
using VegaDatasets

# %% [markdown]
# # Histograms, Density Plots and Line Charts

# %%
# Bring in Cars data set
cars  = dataset("cars") |> 
@select(:Name, :Origin, :Miles_per_Gallon, :Cylinders, :Horsepower) |>
DataFrame

first(cars, 4)
# Out:
# 4×5 DataFrame
#  Row │ Name                       Origin  Miles_per_Gallon  Cylinders  Horsepo ⋯
#      │ String                     String  Float64?          Int64      Int64?  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ chevrolet chevelle malibu  USA                 18.0          8          ⋯
#    2 │ buick skylark 320          USA                 15.0          8
#    3 │ plymouth satellite         USA                 18.0          8
#    4 │ amc rebel sst              USA                 16.0          8
#                                                                 1 column omitted

# %% [markdown]
# ## 1D Histogram

# %%
# Simple of 1D histogram of variable "Horsepower"

@vlplot(
  data = cars,
  mark = :bar,
  x = {"Horsepower:o", bin = true}, # Bins can be adjusted as : bin={maxbins=n}
  y = "count()",
  title = "1D Histogram",
  width = 400,
  height = 400
)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark="bar",
#     title="1D Histogram",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             bin=true,
#             field="Horsepower",
#             type="ordinal"
#         },
#         y={
#             aggregate="count",
#             type="quantitative"
#         }
#     }
# )

# %% [markdown]
# ## Density Plot

# %%
@vlplot(
  data = cars,
  mark = :area, # It's an area plot
  transform = [{density = "Horsepower"}], # For counts add in : counts = true
  x = {"value:q"},
  y = {"density:q"},  # Density variable created
  title = "Density Plot",
  width = 400,
  height = 400


)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark="area",
#     transform=[
#         {
#             density="Horsepower"
#         }
#     ],
#     title="Density Plot",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             field="value",
#             type="quantitative"
#         },
#         y={
#             field="density",
#             type="quantitative"
#         }
#     }
# )

# %% [markdown]
# ## Density Plot by Groups

# %%
@vlplot(
  data = cars,
  mark = :area, # It's an area plot
  transform = [{density = "Horsepower", groupby = ["Cylinders"]}], # Add in groupby variable
  x = {"value:q"},
  y = {"density:q"},  # Density variable created
  color = "Cylinders:n",
  title = "Density Plot by Groups",
  width = 400,
  height = 400
)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark="area",
#     transform=[
#         {
#             density="Horsepower",
#             groupby=[
#                 "Cylinders"
#             ]
#         }
#     ],
#     title="Density Plot by Groups",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             field="value",
#             type="quantitative"
#         },
#         y={
#             field="density",
#             type="quantitative"
#         },
#         color={
#             field="Cylinders",
#             type="nominal"
#         }
#     }
# )

# %%
# Get Movie Data

movies = dataset("movies") |> 
@select(:Title, :IMDB_Rating, :Rotten_Tomatoes_Rating) |>  
@filter(!isna(_.IMDB_Rating) && !isna(_.Rotten_Tomatoes_Rating)) |>  # Filter for not null values
DataFrame;
first(movies,4)
# Out:
# 4×3 DataFrame
#  Row │ Title            IMDB_Rating  Rotten_Tomatoes_Rating
#      │ Any              Float64?     Union{Missing, Int64}
# ─────┼──────────────────────────────────────────────────────
#    1 │ Slam                     3.4                      62
#    2 │ Pirates                  5.8                      25
#    3 │ Duel in the Sun          7.0                      86
#    4 │ Tom Jones                7.0                      81

# %% [markdown]
# ## 2D Histogram Scatterplot

# %%
@vlplot(
  title = "2D Histogram Scatterplot",
  data = movies,
  mark = :circle, # The mark is a circle for scatterplot
  x = {"IMDB_Rating:q", bin={maxbins=10}}, # The x is binned, bin={maxbins=n} to control 
  y = {"Rotten_Tomatoes_Rating:q", bin={maxbins=10}}, # The y value is binned and ordered desending, bin={maxbins=n} to control
  size = "count():q",
  width = 400,
  height = 400

)
# Out:
# @vlplot(
#     title="2D Histogram Scatterplot",
#     data={
#         values=...
#     },
#     mark="circle",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             bin={
#                 maxbins=10
#             },
#             field="IMDB_Rating",
#             type="quantitative"
#         },
#         y={
#             bin={
#                 maxbins=10
#             },
#             field="Rotten_Tomatoes_Rating",
#             type="quantitative"
#         },
#         size={
#             aggregate="count",
#             type="quantitative"
#         }
#     }
# )

# %% [markdown]
# ## 2D Histogram Heatmap

# %%
@vlplot(
  title = "2D Histogram Heatmap",
  data = movies,
  mark = :rect, # The mark is a circle for scatterplot
  x = {"IMDB_Rating:o", bin = true}, # The x is binned, bin={maxbins=n} to control 
  y = {"Rotten_Tomatoes_Rating:o", bin = true, sort = "-x"}, # The y value is binned and ordered desending, bin={maxbins=n} to control
  color = "count()",
  width = 400,
  height = 400

)
# Out:
# @vlplot(
#     title="2D Histogram Heatmap",
#     data={
#         values=...
#     },
#     mark="rect",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             bin=true,
#             field="IMDB_Rating",
#             type="ordinal"
#         },
#         y={
#             bin=true,
#             sort="-x",
#             field="Rotten_Tomatoes_Rating",
#             type="ordinal"
#         },
#         color={
#             aggregate="count",
#             type="quantitative"
#         }
#     }
# )

# %%
# Preview of cars data

first(cars, 4)
# Out:
# 4×5 DataFrame
#  Row │ Name                       Origin  Miles_per_Gallon  Cylinders  Horsepo ⋯
#      │ String                     String  Float64?          Int64      Int64?  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ chevrolet chevelle malibu  USA                 18.0          8          ⋯
#    2 │ buick skylark 320          USA                 15.0          8
#    3 │ plymouth satellite         USA                 18.0          8
#    4 │ amc rebel sst              USA                 16.0          8
#                                                                 1 column omitted

# %% [markdown]
# ## Table Heatmap 1

# %%
@vlplot(
  data = cars,
  mark = :rect,
  x = "Cylinders:n",
  y = "Origin:n",
  color = "mean(Horsepower)",
  title = "Table Heatmap 1",
  width = 400,
  height = 400

)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark="rect",
#     title="Table Heatmap 1",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             field="Cylinders",
#             type="nominal"
#         },
#         y={
#             field="Origin",
#             type="nominal"
#         },
#         color={
#             aggregate="mean",
#             field="Horsepower",
#             type="quantitative"
#         }
#     }
# )

# %%
# Seatle Weather Data
using Dates

seattle_temp = dataset("seattle-temps") |>
DataFrame;

first(seattle_temp, 4)
# Out:
# 4×2 DataFrame
#  Row │ date                       temp
#      │ String                     Float64
# ─────┼────────────────────────────────────
#    1 │ 2010-01-01T01:00:00-08:00     39.2
#    2 │ 2010-01-01T02:00:00-08:00     39.0
#    3 │ 2010-01-01T03:00:00-08:00     38.9
#    4 │ 2010-01-01T04:00:00-08:00     38.8

# %% [markdown]
# ## Table Heatmap 2

# %%
@vlplot(
  data = seattle_temp,
  mark = :rect,
  x = {"date(date):o", title = "Day"}, # o indicates an ordinal scale
  y = {"month(date):o", title = "Month"}, # o indicates an ordinal scale
  color = "max(temp):q",
  width = 500,
  title = "Maximum Daily Temperature per Month",
    

)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark="rect",
#     width=500,
#     title="Maximum Daily Temperature per Month",
#     encoding={
#         x={
#             title="Day",
#             timeUnit="date",
#             field="date",
#             type="ordinal"
#         },
#         y={
#             title="Month",
#             timeUnit="month",
#             field="date",
#             type="ordinal"
#         },
#         color={
#             aggregate="max",
#             field="temp",
#             type="quantitative"
#         }
#     }
# )

# %%
# Google Stock Data

google_stock= dataset("stocks") |>
@filter(_.symbol == "GOOG") |>
DataFrame;

first(google_stock, 4)
# Out:
# 4×3 DataFrame
#  Row │ symbol  date        price
#      │ String  String      Float64
# ─────┼─────────────────────────────
#    1 │ GOOG    Aug 1 2004   102.37
#    2 │ GOOG    Sep 1 2004   129.6
#    3 │ GOOG    Oct 1 2004   190.64
#    4 │ GOOG    Nov 1 2004   181.98

# %% [markdown]
# ## Line Plot

# %%
@vlplot(
  data = google_stock,
  mark = :line,
  x = "date:t",
  y = "price",
  title = "Line Plot",
  width = 400,
  height = 400
)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark="line",
#     title="Line Plot",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             field="date",
#             type="temporal"
#         },
#         y={
#             field="price"
#         }
#     }
# )

# %% [markdown]
# ## Step Chart

# %%
@vlplot(
  data = google_stock,
  mark = {:line, interpolate="step-after"}, # interpolate="step-after"
  x = "date:t",
  y = "price",
  title = "Step Chart",
  width = 400,
  height = 400
    

)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark={
#         interpolate="step-after",
#         type="line"
#     },
#     title="Step Chart",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             field="date",
#             type="temporal"
#         },
#         y={
#             field="price"
#         }
#     }
# )

# %% [markdown]
# ## Line Chart with Monotone Interpolation

# %%
@vlplot(
  data = google_stock,
  mark = {:line, interpolate="monotone"}, # interpolate="step-after"
  x = "date:t",
  y = "price",
  title = "Line Chart with Monotone Interpolation",
  width = 400,
  height = 400
)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark={
#         interpolate="monotone",
#         type="line"
#     },
#     title="Line Chart with Monotone Interpolation",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             field="date",
#             type="temporal"
#         },
#         y={
#             field="price"
#         }
#     }
# )

# %% [markdown]
# ## Line Chart with Point Markers

# %%
@vlplot(
  data = google_stock,
  mark = {:line, point = true}, # Here indicate point = true
  x = "year(date)",  # Function that maps each date into year
  y = "mean(price)", # The mean price over each year
  title = "Line Chart with Point Markers",
  width = 400,
  height = 400
)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark={
#         point=true,
#         type="line"
#     },
#     title="Line Chart with Point Markers",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             timeUnit="year",
#             field="date",
#             type="temporal"
#         },
#         y={
#             aggregate="mean",
#             field="price",
#             type="quantitative"
#         }
#     }
# )

# %%
stocks = dataset("stocks") |> DataFrame;
first(stocks, 4)
# Out:
# 4×3 DataFrame
#  Row │ symbol  date        price
#      │ String  String      Float64
# ─────┼─────────────────────────────
#    1 │ MSFT    Jan 1 2000    39.81
#    2 │ MSFT    Feb 1 2000    36.35
#    3 │ MSFT    Mar 1 2000    43.22
#    4 │ MSFT    Apr 1 2000    28.37

# %% [markdown]
# ## Line Chart by Class

# %%
p1= 
@vlplot(
  data = stocks,
  mark = :line,
  x = "date:t",
  y = "price",
  title = "Line Chart by Class",
  color = "symbol:n",
  width = 400,
  height = 400
)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark="line",
#     title="Line Chart by Class",
#     width=400,
#     height=400,
#     encoding={
#         x={
#             field="date",
#             type="temporal"
#         },
#         y={
#             field="price"
#         },
#         color={
#             field="symbol",
#             type="nominal"
#         }
#     }
# )
